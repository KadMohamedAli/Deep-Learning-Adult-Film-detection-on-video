# %%
import os
import sys
import cv2
import librosa
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from moviepy.editor import VideoFileClip
import imageio
import matplotlib.pyplot as plt
import wave
import resampy
import soundfile as sf
import sounddevice as sd

# %%
img_height, img_width = 299, 299

# %%
# Load pre-trained models
inception_model = tf.keras.applications.InceptionV3(include_top=False, weights='imagenet',pooling='avg' ,input_shape=(img_height, img_width, 3))
audiovgg_model = hub.load('https://kaggle.com/models/google/vggish/frameworks/TensorFlow2/variations/vggish/versions/1')

# %%
def preprocess_frame(frame):
    # Resize frame to (299, 299)
    resized_frame = cv2.resize(frame, (299, 299))
    # Scale pixel values to the range [0, 1]
    processed_frame = resized_frame.astype("float32") / 255.0
    # Expand dimensions to match the expected shape
    processed_frame = np.expand_dims(processed_frame, axis=0)
    return processed_frame

def preprocess_audio(audio):
    try:
        audio_data = audio.to_soundarray()
        
        # Check for NaN or Infinite values and handle them
        audio_data[np.isnan(audio_data) | np.isinf(audio_data)] = 0
        
        # Convert stereo to mono
        if len(audio_data.shape) > 1:
            audio_data = np.mean(audio_data, axis=1)
        
        # Normalize audio to range [-1.0, +1.0]
        max_abs_value = np.max(np.abs(audio_data))
        if max_abs_value > 0:
            audio_data /= max_abs_value

        # Pad if duration is less than 0.96 seconds
        target_length = int(audio.fps * 0.96)
        audio_data = np.pad(audio_data, (0, max(0, target_length - len(audio_data))), mode='constant')

        # Resample the audio to the target sample rate
        preprocessed_audio = librosa.resample(y=audio_data, orig_sr=audio.fps, target_sr=44100)

        return preprocessed_audio.astype(np.float32)

    except Exception as e:
        print("Error preprocessing audio:", e)
        return np.zeros((44100,), dtype=np.float32)

# %%
# Function to extract frames and audio from a video segment
def extract_frames_and_audio(video, output_dir, start_time, end_time, segment_index,clip_index):
    if end_time - start_time <= 0:
        return None, None  # Return None for both visual and audio if segment duration is invalid
    
    frame = video.get_frame((start_time+end_time)/2)
    #plt.imshow(frame)
    #plt.axis('off')  
    #plt.show()
    
    audio = video.subclip(start_time, end_time).audio
    if audio is None:
        return inception_model.predict(preprocess_frame(frame), verbose=0), None  # Return None for audio if it's not available
    if frame is None:
        print('NO FRAME HERE !!!!!!!!!!!')
    
    #audio_np = np.array(audio.to_soundarray())
    #sample_rate = int(audio.fps)  
    #sd.play(audio_np, samplerate=sample_rate)

    return inception_model.predict(preprocess_frame(frame), verbose=0),audiovgg_model(preprocess_audio(audio))[0]

# %%
def extract_visual_and_audio_features(folder_path, output_dir, output_filename, segment_duration=1, num_segments=10, clip_duration=10):
    VAn=0
    VnA=0
    VnAn=0
    VA=0

    # Loop through each video file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith('.mp4'):  # Assuming all video files are in mp4 format
            # Initialize a list to store visual and audio data
            all_visual_and_audio_data = []
                        
            video_path = os.path.join(folder_path, filename)
            # Load the video file
            video = VideoFileClip(video_path)

            videoName=os.path.splitext(os.path.basename(video.filename))[0]
            print('Video : ',videoName)
            # Total duration of the video clip
            total_duration = video.duration
            
            # Number of clips to extract
            total_clips = int(total_duration // clip_duration)
            remaining_duration = total_duration % clip_duration
            
            if remaining_duration > 0:
                total_clips += 1
             
            # Determine the rounded clip duration
            rounded_clip_duration = int(total_duration / total_clips)
            
            # Loop through each complete clip
            for clip_index in range(total_clips):
                # Set the start and end time of the clip
                start_time = clip_index * rounded_clip_duration
                end_time = min(start_time + rounded_clip_duration, total_duration)
                 
                # Initialize array for visual and audio features for this clip
                clip_visual_and_audio = []

                # Loop through each segment in the clip
                for segment_index in range(num_segments):
                    # Set the start and end time of the segment
                    segment_start_time = start_time + segment_index * segment_duration
                    segment_end_time = min(segment_start_time + segment_duration, end_time)
                    
                    # Extract frames and audio from the segment
                    visual, audio = extract_frames_and_audio(video, output_dir, segment_start_time, segment_end_time, segment_index, clip_index)
                    # Check if visual and audio are None
                    if visual is None and audio is not None:
                        # Set visual to zeros
                        visual_flat = np.zeros((2048,))
                        # Flatten the audio array
                        audio_flat = audio.numpy().flatten()
                        
                        VnA+=1
                    elif visual is not None and audio is None:
                        # Flatten the visual array
                        visual_flat = visual.flatten()
                        # Set audio to zeros
                        audio_flat = np.zeros((128,))
                        
                        VAn+=1
                    elif visual is None and audio is None:
                        # Both visual and audio are None, handle accordingly (here both are set to zeros)
                        visual_flat = np.zeros((2048,))
                        audio_flat = np.zeros((128,))
                        
                        VnAn+=1
                    else:
                        # Both visual and audio are not None, handle accordingly (flattening both)
                        visual_flat = visual.flatten()
                        audio_flat = audio.numpy().flatten()
                        
                        VA+=1
                    # Concatenate visual and audio features and append to clip array
                    visual_and_audio = np.concatenate((visual_flat, audio_flat), axis=0)
                    clip_visual_and_audio.append(visual_and_audio)
                
                # Append visual and audio features for this clip to the main array
                all_visual_and_audio_data.append(clip_visual_and_audio)
                
                        
            # Close the video file
            video.close()
        
            # Convert the list to numpy array
            all_visual_and_audio_data = np.array(all_visual_and_audio_data)
        
            # Save visual and audio data to numpy array
            array_path = os.path.join(output_dir, videoName+'.npy')
            np.save(array_path, all_visual_and_audio_data)
            print(f"Visual and audio data saved to {array_path}, shape is : {all_visual_and_audio_data.shape}")

    total=VnA+VAn+VnAn+VA
    print('Total features traiter : ',str(VnA+VAn+VnAn+VA))
    print('no audio no visual     : ',str(VnAn) ,' Pourcentage : ',str(VnAn/total))
    print('audio and visual       : ',str(VA),' Pourcentage : ',str(VA/total))
    print('visual but no audio    : ',str(VAn),' Pourcentage : ',str(VAn/total))
    print('audio but no visual    : ',str(VnA)),' Pourcentage : ',str(VnA/total)

# %%
# Path to the folder containing video files
folder_path = r'A:\AI DB\LSPD\Videos\porn_final'
output_dir = r'A:\AI DB\LSPD\Videos\Features_Porn'
output_filename = 'porn_features.npy'

extract_visual_and_audio_features(folder_path, output_dir, output_filename)

# %%
# Path to the folder containing video files
folder_path2 = r'A:\AI DB\LSPD\Videos\normal_final'
output_dir2 = r'A:\AI DB\LSPD\Videos\Features_Normal'
output_filename2 = 'normal_features.npy'

extract_visual_and_audio_features(folder_path2, output_dir2, output_filename2)
# Out:
# Video :  nonporn_1
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1.npy, shape is : (2, 10, 2176)
# Video :  nonporn_10
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_10.npy, shape is : (36, 10, 2176)
# Video :  nonporn_100
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_100.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1000
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1000.npy, shape is : (10, 10, 2176)
# Video :  nonporn_1001
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1001.npy, shape is : (15, 10, 2176)
# Video :  nonporn_1002
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1002.npy, shape is : (19, 10, 2176)
# Video :  nonporn_1003
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1003.npy, shape is : (13, 10, 2176)
# Video :  nonporn_1004
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1004.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1005
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1005.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1006
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1006.npy, shape is : (11, 10, 2176)
# Video :  nonporn_1007
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1007.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1008
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1008.npy, shape is : (24, 10, 2176)
# Video :  nonporn_1009
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1009.npy, shape is : (6, 10, 2176)
# Video :  nonporn_101
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_101.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1010
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1010.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1011
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1011.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1012
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1012.npy, shape is : (26, 10, 2176)
# Video :  nonporn_1013
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1013.npy, shape is : (35, 10, 2176)
# Video :  nonporn_1014
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1014.npy, shape is : (7, 10, 2176)
# Video :  nonporn_1015
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1015.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1016
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1016.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1017
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1017.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1018
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1018.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1019
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1019.npy, shape is : (3, 10, 2176)
# Video :  nonporn_102
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_102.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1020
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1020.npy, shape is : (14, 10, 2176)
# Video :  nonporn_1021
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1021.npy, shape is : (157, 10, 2176)
# Video :  nonporn_1022
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1022.npy, shape is : (75, 10, 2176)
# Video :  nonporn_1023
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1023.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1024
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1024.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1025
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1025.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1026
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1026.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1027
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1027.npy, shape is : (18, 10, 2176)
# Video :  nonporn_1028
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1028.npy, shape is : (14, 10, 2176)
# Video :  nonporn_1029
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1029.npy, shape is : (5, 10, 2176)
# Video :  nonporn_103
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_103.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1030
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1030.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1031
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1031.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1032
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1032.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1033
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1033.npy, shape is : (42, 10, 2176)
# Video :  nonporn_1034
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1034.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1035
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1035.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1036
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1036.npy, shape is : (72, 10, 2176)
# Video :  nonporn_1037
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1037.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1038
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1038.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1039
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1039.npy, shape is : (3, 10, 2176)
# Video :  nonporn_104
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_104.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1040
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1040.npy, shape is : (62, 10, 2176)
# Video :  nonporn_1041
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1041.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1042
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1042.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1043
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1043.npy, shape is : (35, 10, 2176)
# Video :  nonporn_1044
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1044.npy, shape is : (124, 10, 2176)
# Video :  nonporn_1045
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1045.npy, shape is : (139, 10, 2176)
# Video :  nonporn_1046
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1046.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1047
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1047.npy, shape is : (47, 10, 2176)
# Video :  nonporn_1048
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1048.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1049
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1049.npy, shape is : (3, 10, 2176)
# Video :  nonporn_105
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_105.npy, shape is : (161, 10, 2176)
# Video :  nonporn_1050
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1050.npy, shape is : (81, 10, 2176)
# Video :  nonporn_1051
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1051.npy, shape is : (7, 10, 2176)
# Video :  nonporn_1052
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1052.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1053
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1053.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1054
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1054.npy, shape is : (13, 10, 2176)
# Video :  nonporn_1055
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1055.npy, shape is : (10, 10, 2176)
# Video :  nonporn_1056
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1056.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1057
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1057.npy, shape is : (9, 10, 2176)
# Video :  nonporn_1058
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1058.npy, shape is : (1, 10, 2176)
# Video :  nonporn_1059
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1059.npy, shape is : (2, 10, 2176)
# Video :  nonporn_106
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_106.npy, shape is : (13, 10, 2176)
# Video :  nonporn_1060
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1060.npy, shape is : (16, 10, 2176)
# Video :  nonporn_1061
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1061.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1062
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1062.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1063
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1063.npy, shape is : (13, 10, 2176)
# Video :  nonporn_1064
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1064.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1065
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1065.npy, shape is : (9, 10, 2176)
# Video :  nonporn_1066
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1066.npy, shape is : (7, 10, 2176)
# Video :  nonporn_1067
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1067.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1068
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1068.npy, shape is : (1, 10, 2176)
# Video :  nonporn_1069
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1069.npy, shape is : (5, 10, 2176)
# Video :  nonporn_107
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_107.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1070
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1070.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1071
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1071.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1072
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1072.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1073
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1073.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1074
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1074.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1075
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1075.npy, shape is : (27, 10, 2176)
# Video :  nonporn_1076
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1076.npy, shape is : (14, 10, 2176)
# Video :  nonporn_1077
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1077.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1078
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1078.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1079
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1079.npy, shape is : (2, 10, 2176)
# Video :  nonporn_108
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_108.npy, shape is : (20, 10, 2176)
# Video :  nonporn_1080
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1080.npy, shape is : (19, 10, 2176)
# Video :  nonporn_1081
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1081.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1082
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1082.npy, shape is : (13, 10, 2176)
# Video :  nonporn_1083
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1083.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1084
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1084.npy, shape is : (1, 10, 2176)
# Video :  nonporn_1085
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1085.npy, shape is : (20, 10, 2176)
# Video :  nonporn_1086
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1086.npy, shape is : (9, 10, 2176)
# Video :  nonporn_1087
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1087.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1088
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1088.npy, shape is : (10, 10, 2176)
# Video :  nonporn_1089
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1089.npy, shape is : (36, 10, 2176)
# Video :  nonporn_109
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_109.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1090
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1090.npy, shape is : (10, 10, 2176)
# Video :  nonporn_1091
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1091.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1092
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1092.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1093
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1093.npy, shape is : (10, 10, 2176)
# Video :  nonporn_1094
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1094.npy, shape is : (8, 10, 2176)
# Video :  nonporn_1095
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1095.npy, shape is : (8, 10, 2176)
# Video :  nonporn_1096
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1096.npy, shape is : (34, 10, 2176)
# Video :  nonporn_1097
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1097.npy, shape is : (34, 10, 2176)
# Video :  nonporn_1098
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1098.npy, shape is : (20, 10, 2176)
# Video :  nonporn_1099
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1099.npy, shape is : (42, 10, 2176)
# Video :  nonporn_11
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28096 (out of a total 35078 frames), at time 937.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28081 (out of a total 35078 frames), at time 936.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28126 (out of a total 35078 frames), at time 938.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28111 (out of a total 35078 frames), at time 937.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28156 (out of a total 35078 frames), at time 939.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28141 (out of a total 35078 frames), at time 938.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28186 (out of a total 35078 frames), at time 940.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28171 (out of a total 35078 frames), at time 939.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28216 (out of a total 35078 frames), at time 941.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28201 (out of a total 35078 frames), at time 940.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28246 (out of a total 35078 frames), at time 942.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28231 (out of a total 35078 frames), at time 941.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28276 (out of a total 35078 frames), at time 943.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28261 (out of a total 35078 frames), at time 942.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28306 (out of a total 35078 frames), at time 944.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28291 (out of a total 35078 frames), at time 943.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28336 (out of a total 35078 frames), at time 945.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28321 (out of a total 35078 frames), at time 944.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28366 (out of a total 35078 frames), at time 946.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28351 (out of a total 35078 frames), at time 945.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28396 (out of a total 35078 frames), at time 947.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28381 (out of a total 35078 frames), at time 946.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28426 (out of a total 35078 frames), at time 948.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28411 (out of a total 35078 frames), at time 947.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28456 (out of a total 35078 frames), at time 949.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28441 (out of a total 35078 frames), at time 948.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28486 (out of a total 35078 frames), at time 950.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28471 (out of a total 35078 frames), at time 949.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28516 (out of a total 35078 frames), at time 951.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28501 (out of a total 35078 frames), at time 950.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28546 (out of a total 35078 frames), at time 952.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28531 (out of a total 35078 frames), at time 951.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28576 (out of a total 35078 frames), at time 953.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28561 (out of a total 35078 frames), at time 952.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28606 (out of a total 35078 frames), at time 954.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28591 (out of a total 35078 frames), at time 953.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28636 (out of a total 35078 frames), at time 955.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28621 (out of a total 35078 frames), at time 954.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28666 (out of a total 35078 frames), at time 956.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28651 (out of a total 35078 frames), at time 955.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28696 (out of a total 35078 frames), at time 957.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28681 (out of a total 35078 frames), at time 956.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28726 (out of a total 35078 frames), at time 958.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28711 (out of a total 35078 frames), at time 957.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28756 (out of a total 35078 frames), at time 959.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28741 (out of a total 35078 frames), at time 958.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28786 (out of a total 35078 frames), at time 960.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28771 (out of a total 35078 frames), at time 959.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28816 (out of a total 35078 frames), at time 961.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28801 (out of a total 35078 frames), at time 960.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28846 (out of a total 35078 frames), at time 962.49/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28831 (out of a total 35078 frames), at time 961.99/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28876 (out of a total 35078 frames), at time 963.50/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28861 (out of a total 35078 frames), at time 963.00/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28906 (out of a total 35078 frames), at time 964.50/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28891 (out of a total 35078 frames), at time 964.00/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28936 (out of a total 35078 frames), at time 965.50/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28921 (out of a total 35078 frames), at time 965.00/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28966 (out of a total 35078 frames), at time 966.50/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28951 (out of a total 35078 frames), at time 966.00/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28996 (out of a total 35078 frames), at time 967.50/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 28981 (out of a total 35078 frames), at time 967.00/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29025 (out of a total 35078 frames), at time 968.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29010 (out of a total 35078 frames), at time 967.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29055 (out of a total 35078 frames), at time 969.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29040 (out of a total 35078 frames), at time 968.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29085 (out of a total 35078 frames), at time 970.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29070 (out of a total 35078 frames), at time 969.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29115 (out of a total 35078 frames), at time 971.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29100 (out of a total 35078 frames), at time 970.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29145 (out of a total 35078 frames), at time 972.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29130 (out of a total 35078 frames), at time 971.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29175 (out of a total 35078 frames), at time 973.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29160 (out of a total 35078 frames), at time 972.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29205 (out of a total 35078 frames), at time 974.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29190 (out of a total 35078 frames), at time 973.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29235 (out of a total 35078 frames), at time 975.47/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29220 (out of a total 35078 frames), at time 974.97/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29265 (out of a total 35078 frames), at time 976.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29250 (out of a total 35078 frames), at time 975.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29295 (out of a total 35078 frames), at time 977.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29280 (out of a total 35078 frames), at time 976.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29325 (out of a total 35078 frames), at time 978.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29310 (out of a total 35078 frames), at time 977.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29355 (out of a total 35078 frames), at time 979.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29340 (out of a total 35078 frames), at time 978.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29385 (out of a total 35078 frames), at time 980.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29370 (out of a total 35078 frames), at time 979.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29415 (out of a total 35078 frames), at time 981.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29400 (out of a total 35078 frames), at time 980.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29445 (out of a total 35078 frames), at time 982.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29430 (out of a total 35078 frames), at time 981.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29475 (out of a total 35078 frames), at time 983.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29460 (out of a total 35078 frames), at time 982.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29505 (out of a total 35078 frames), at time 984.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29490 (out of a total 35078 frames), at time 983.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29535 (out of a total 35078 frames), at time 985.48/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:154: UserWarning: In file A:\AI DB\LSPD\Videos\normal_final\nonporn_11.mp4, 921600 bytes wanted but 0 bytes read,at frame index 29520 (out of a total 35078 frames), at time 984.98/1170.45 sec. Using the last valid frame instead.
#   warnings.warn(
# ...
# Video :  nonporn_1321
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1321.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1322
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1322.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1323
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1323.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1324
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1324.npy, shape is : (28, 10, 2176)
# Video :  nonporn_1325
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1325.npy, shape is : (23, 10, 2176)
# Video :  nonporn_1326
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1326.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1327
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1327.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1328
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1328.npy, shape is : (23, 10, 2176)
# Video :  nonporn_1329
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1329.npy, shape is : (2, 10, 2176)
# Video :  nonporn_133
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_133.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1330
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1330.npy, shape is : (8, 10, 2176)
# Video :  nonporn_1331
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1331.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1332
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1332.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1333
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1333.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1334
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1334.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1335
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1335.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1336
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1336.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1337
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1337.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1338
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1338.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1339
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1339.npy, shape is : (3, 10, 2176)
# Video :  nonporn_134
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_134.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1340
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1340.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1341
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1341.npy, shape is : (73, 10, 2176)
# Video :  nonporn_1342
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1342.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1343
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1343.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1344
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1344.npy, shape is : (8, 10, 2176)
# Video :  nonporn_1345
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1345.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1346
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1346.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1347
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1347.npy, shape is : (9, 10, 2176)
# Video :  nonporn_1348
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1348.npy, shape is : (23, 10, 2176)
# Video :  nonporn_1349
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1349.npy, shape is : (2, 10, 2176)
# Video :  nonporn_135
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_135.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1350
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1350.npy, shape is : (70, 10, 2176)
# Video :  nonporn_1351
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1351.npy, shape is : (31, 10, 2176)
# Video :  nonporn_1352
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1352.npy, shape is : (41, 10, 2176)
# Video :  nonporn_1353
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1353.npy, shape is : (83, 10, 2176)
# Video :  nonporn_1354
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1354.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1355
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1355.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1356
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1356.npy, shape is : (16, 10, 2176)
# Video :  nonporn_1357
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1357.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1358
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1358.npy, shape is : (7, 10, 2176)
# Video :  nonporn_1359
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1359.npy, shape is : (25, 10, 2176)
# Video :  nonporn_136
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_136.npy, shape is : (13, 10, 2176)
# Video :  nonporn_1360
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1360.npy, shape is : (12, 10, 2176)
# Video :  nonporn_1361
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1361.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1362
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1362.npy, shape is : (7, 10, 2176)
# Video :  nonporn_1363
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1363.npy, shape is : (12, 10, 2176)
# Video :  nonporn_1364
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1364.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1365
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1365.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1366
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1366.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1367
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1367.npy, shape is : (7, 10, 2176)
# Video :  nonporn_1368
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1368.npy, shape is : (11, 10, 2176)
# Video :  nonporn_1369
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1369.npy, shape is : (3, 10, 2176)
# Video :  nonporn_137
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_137.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1370
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1370.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1371
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1371.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1372
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1372.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1373
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1373.npy, shape is : (52, 10, 2176)
# Video :  nonporn_1374
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1374.npy, shape is : (238, 10, 2176)
# Video :  nonporn_1375
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1375.npy, shape is : (46, 10, 2176)
# Video :  nonporn_1376
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1376.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1377
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1377.npy, shape is : (67, 10, 2176)
# Video :  nonporn_1378
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1378.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1379
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1379.npy, shape is : (108, 10, 2176)
# Video :  nonporn_138
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_138.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1380
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1380.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1381
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1381.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1382
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1382.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1383
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1383.npy, shape is : (148, 10, 2176)
# Video :  nonporn_1384
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1384.npy, shape is : (3, 10, 2176)
# Video :  nonporn_1385
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1385.npy, shape is : (6, 10, 2176)
# Video :  nonporn_1386
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1386.npy, shape is : (2, 10, 2176)
# Video :  nonporn_1387
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1387.npy, shape is : (75, 10, 2176)
# Video :  nonporn_1388
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1388.npy, shape is : (42, 10, 2176)
# Video :  nonporn_1389
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1389.npy, shape is : (62, 10, 2176)
# Video :  nonporn_139
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_139.npy, shape is : (51, 10, 2176)
# Video :  nonporn_1390
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1390.npy, shape is : (61, 10, 2176)
# Video :  nonporn_1391
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1391.npy, shape is : (83, 10, 2176)
# Video :  nonporn_1392
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1392.npy, shape is : (34, 10, 2176)
# Video :  nonporn_1393
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1393.npy, shape is : (36, 10, 2176)
# Video :  nonporn_1394
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1394.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1395
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1395.npy, shape is : (5, 10, 2176)
# Video :  nonporn_1396
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1396.npy, shape is : (11, 10, 2176)
# Video :  nonporn_1397
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1397.npy, shape is : (28, 10, 2176)
# Video :  nonporn_1398
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1398.npy, shape is : (25, 10, 2176)
# Video :  nonporn_1399
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1399.npy, shape is : (21, 10, 2176)
# Video :  nonporn_14
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_14.npy, shape is : (2, 10, 2176)
# Video :  nonporn_140
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_140.npy, shape is : (4, 10, 2176)
# Video :  nonporn_1400
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1400.npy, shape is : (28, 10, 2176)
# Video :  nonporn_1401
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1401.npy, shape is : (41, 10, 2176)
# Video :  nonporn_1402
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1402.npy, shape is : (14, 10, 2176)
# Video :  nonporn_1403
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1403.npy, shape is : (10, 10, 2176)
# Video :  nonporn_1404
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1404.npy, shape is : (34, 10, 2176)
# Video :  nonporn_1405
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1405.npy, shape is : (12, 10, 2176)
# Video :  nonporn_1406
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1406.npy, shape is : (34, 10, 2176)
# Video :  nonporn_1407
# Visual and audio data saved to A:\AI DB\LSPD\Videos\Features_Normal\nonporn_1407.npy, shape is : (19, 10, 2176)
# Video :  nonporn_1408
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 6
#       3 output_dir2 = r'A:\AI DB\LSPD\Videos\Features_Normal'
#       4 output_filename2 = 'normal_features.npy'
# ----> 6 extract_visual_and_audio_features(folder_path2, output_dir2, output_filename2)
#
# Cell In[13], line 48, in extract_visual_and_audio_features(folder_path, output_dir, output_filename, segment_duration, num_segments, clip_duration)
#      45 segment_end_time = min(segment_start_time + segment_duration, end_time)
#      47 # Extract frames and audio from the segment
# ---> 48 visual, audio = extract_frames_and_audio(video, output_dir, segment_start_time, segment_end_time, segment_index, clip_index)
#      49 # Check if visual and audio are None
#      50 if visual is None and audio is not None:
#      51     # Set visual to zeros
#
# Cell In[12], line 6, in extract_frames_and_audio(video, output_dir, start_time, end_time, segment_index, clip_index)
#       3 if end_time - start_time <= 0:
#       4     return None, None  # Return None for both visual and audio if segment duration is invalid
# ----> 6 frame = video.get_frame((start_time+end_time)/2)
#       7 #plt.imshow(frame)
#       8 #plt.axis('off')
#       9 #plt.show()
#      11 audio = video.subclip(start_time, end_time).audio
#
# File <decorator-gen-29>:2, in get_frame(self, t)
#
# File C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\decorators.py:89, in preprocess_args.<locals>.wrapper(f, *a, **kw)
#      84 new_a = [
#      85     fun(arg) if (name in varnames) and (arg is not None) else arg
#      86     for (arg, name) in zip(a, names)
#      87 ]
#      88 new_kw = {k: fun(v) if k in varnames else v for (k, v) in kw.items()}
# ---> 89 return f(*new_a, **new_kw)
#
# File C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\Clip.py:98, in Clip.get_frame(self, t)
#      95         return frame
#      96 else:
#      97     # print(t)
# ---> 98     return self.make_frame(t)
#
# File C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\VideoFileClip.py:136, in VideoFileClip.__init__.<locals>.<lambda>(t)
#     132     self.mask.fps = self.fps
#     134 else:
# --> 136     self.make_frame = lambda t: self.reader.get_frame(t)
#     138 # Make a reader for the audio, if any.
#     139 if audio and self.reader.infos["audio_found"]:
#
# File C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:217, in FFMPEG_VideoReader.get_frame(self, t)
#     214     return self.lastread
#     215 else:
#     216     # If pos == self.pos + 1, this line has no effect
# --> 217     self.skip_frames(pos - self.pos - 1)
#     218     result = self.read_frame()
#     219     return result
#
# File C:\ProgramData\anaconda3\envs\amchibrk\lib\site-packages\moviepy\video\io\ffmpeg_reader.py:137, in FFMPEG_VideoReader.skip_frames(self, n)
#     135 w, h = self.size
#     136 for i in range(n):
# --> 137     self.proc.stdout.read(self.depth * w * h)
#     139     # self.proc.stdout.flush()
#     140 self.pos += n
#
# KeyboardInterrupt:

# %%
visual_and_audio_data = np.load(array_path, allow_pickle=True)
num_samples = len(visual_and_audio_data)
labels = np.ones(num_samples)  # Create labels filled with 1 indicating "porno"

# %%
print(" visual audio data shape : ",visual_and_audio_data.shape)
